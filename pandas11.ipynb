# %%
import pandas as pd
df=pd.read_excel('stack_data.xlsx')
df
# Out:
#             Unnamed: 0     Price Price.1    Price.2  \
# 0              Company  Facebook  Google  Microsoft
# 1  2017-06-05 00:00:00       155     955         66
# 2  2017-06-06 00:00:00       150     987         69
# 3  2017-06-07 00:00:00       153     963         62
# 4  2017-06-08 00:00:00       155    1000         61
# 5  2017-06-09 00:00:00       156    1012         66
#
#   P/E Price to Earnings Ratio P/E Price to Earnings Ratio.1  \
# 0                    Facebook                        Google
# 1                        37.1                            32
# 2                       36.98                            31
# 3                       36.78                            31
# 4                       36.11                            30
# 5                       37.07                            30
#
#   P/E Price to Earnings Ratio.2
# 0                     Microsoft
# 1                            30
# 2                            30
# 3                            30
# ...
